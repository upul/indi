# %%
import numpy as np
from sklearn.datasets.samples_generator import make_regression
from indi.supervised.regression.linear_regression import LinearRegression
from indi.common.regularizationtype import RegularizationType
import indi.datasets.synthetic.linear as linear 
import matplotlib.pyplot as plt
import seaborn as sbs; sbs.set()
# %matplotlib inline

# %%
x, y = linear.generate_dataset(lambda x: 1.0*x + 2.0, number_of_items=200)
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color = '#dd1c77')
plt.show()

# %%
lr = LinearRegression(learning_rate=0.001,
                          max_iter=100000,
                          regularization_type=None,
                          regularization=1e-3,
                          fit_intercept=True,
                          normalize=False,
                          tolerance=1e-6,
                          verbose=True)
lr.fit(x, y)
y_predict = lr.predict(x)
print(np.count_nonzero(lr.weight))
print(lr.weight)

plt.figure(figsize=(10, 6))
plt.scatter(x, y, color = '#dd1c77')
plt.plot(x, y_predict, color='#c994c7', linewidth=3)
plt.show()
# Out:
# iteration:          1		cost: 2.8817e+01
# iteration:          2		cost: 2.6941e+01
# iteration:          3		cost: 2.5190e+01
# iteration:          4		cost: 2.3557e+01
# iteration:          5		cost: 2.2034e+01
# iteration:          6		cost: 2.0614e+01
# iteration:          7		cost: 1.9288e+01
# iteration:          8		cost: 1.8052e+01
# iteration:          9		cost: 1.6898e+01
# iteration:         10		cost: 1.5823e+01
# iteration:         20		cost: 8.3351e+00
# iteration:         30		cost: 4.5985e+00
# iteration:         40		cost: 2.7333e+00
# iteration:         50		cost: 1.8016e+00
# iteration:         60		cost: 1.3357e+00
# iteration:         70		cost: 1.1022e+00
# iteration:         80		cost: 9.8456e-01
# iteration:         90		cost: 9.2480e-01
# iteration:        100		cost: 8.9391e-01
# iteration:        200		cost: 8.4427e-01
# iteration:        300		cost: 8.2419e-01
# iteration:        400		cost: 8.0509e-01
# iteration:        500		cost: 7.8692e-01
# iteration:        600		cost: 7.6962e-01
# iteration:        700		cost: 7.5315e-01
# iteration:        800		cost: 7.3747e-01
# iteration:        900		cost: 7.2254e-01
# iteration:       1000		cost: 7.0834e-01
# iteration:       2000		cost: 5.9890e-01
# iteration:       3000		cost: 5.3204e-01
# iteration:       4000		cost: 4.9120e-01
# iteration:       5000		cost: 4.6624e-01
# iteration:       6000		cost: 4.5099e-01
# iteration:       7000		cost: 4.4167e-01
# iteration:       8000		cost: 4.3598e-01
# iteration:       9000		cost: 4.3250e-01
# iteration:      10000		cost: 4.3038e-01
# iteration:      20000		cost: 4.2707e-01
# iteration:      30000		cost: 4.2704e-01
# iteration:      40000		cost: 4.2704e-01
# iteration:      50000		cost: 4.2704e-01
#
# Optimization completed: number of iterations: 53069, Norm of gradient of the cost: 9.999196732356885e-07
#
# 2
# [ 2.10194694  0.9761675 ]

# %%
from sklearn.linear_model import LinearRegression

sk_linear_reg = LinearRegression(fit_intercept=True)
sk_linear_reg.fit(x.reshape(x.shape[0], 1), y)
print(sk_linear_reg.coef_)
print(sk_linear_reg.intercept_)
y_prdict = sk_linear_reg.predict(x.reshape(x.shape[0], 1))

plt.figure(figsize=(10, 6))
plt.scatter(x, y, color = '#dd1c77')
plt.plot(x, y_predict, color='#c994c7', linewidth=3)
plt.show()
# Out:
# [ 0.9761669]
# 2.10195095716
