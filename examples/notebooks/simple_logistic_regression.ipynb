# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import numpy.testing as npt
import matplotlib.pylab as plt
import seaborn as sbs; sbs.set()
from sklearn.datasets.samples_generator import make_blobs
from indi.supervised.classification.linear_classifiers import LogisticRegression

# %%
n_samples = 1500
X, y = make_blobs(n_samples=n_samples, centers=2, n_features=2,
                  cluster_std=0.65, random_state=1788)
logistic = LogisticRegression(learning_rate=0.3,
                          max_iter=1250,
                          regularization_type=None,
                          regularization=1e-3,
                          fit_intercept=True,
                          normalize=False,
                          tolerance=1e-4,
                          verbose=True)
logistic.fit(X, y)
# Out:
# iteration:          1		cost: 6.9315e-01
# iteration:          2		cost: 5.6452e-01
# iteration:          3		cost: 1.9028e+00
# iteration:          4		cost: 4.0583e+00
# iteration:          5		cost: 7.1540e-01
# iteration:          6		cost: 2.6145e+00
# iteration:          7		cost: 1.3040e+00
# iteration:          8		cost: 2.4145e+00
# iteration:          9		cost: 6.7964e-01
# iteration:         10		cost: 8.4688e-01
# iteration:         20		cost: 3.0498e-02
# iteration:         30		cost: 2.8528e-02
# iteration:         40		cost: 2.6884e-02
# iteration:         50		cost: 2.5486e-02
# iteration:         60		cost: 2.4282e-02
# iteration:         70		cost: 2.3233e-02
# iteration:         80		cost: 2.2308e-02
# iteration:         90		cost: 2.1487e-02
# iteration:        100		cost: 2.0751e-02
# iteration:        200		cost: 1.6125e-02
# iteration:        300		cost: 1.3774e-02
# iteration:        400		cost: 1.2318e-02
# iteration:        500		cost: 1.1315e-02
# iteration:        600		cost: 1.0575e-02
# iteration:        700		cost: 1.0003e-02
# iteration:        800		cost: 9.5450e-03
# iteration:        900		cost: 9.1692e-03
# iteration:       1000		cost: 8.8542e-03
#
# Optimization completed: number of iterations: 1250, Norm of gradient of the cost: 0.002598717288438967

# %%
h = 0.02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200),
                         np.linspace(y_min, y_max, 100))
Z = logistic.predict(np.c_[xx.ravel(), yy.ravel()])[1]
Z = Z.reshape(xx.shape)
_, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(14, 6))
ax1.scatter(X[:, 0], X[:, 1], c=y, alpha=0.5, edgecolors='none', s=45, cmap=plt.cm.Spectral)
ax2.contourf(xx, yy, Z, alpha=0.5, cmap=plt.cm.Spectral)
ax2.scatter(X[:, 0], X[:, 1], c=y, alpha=0.5, edgecolors='none', cmap=plt.cm.Spectral, s=45)

plt.xlim(X[:, 0].min(), X[:, 0].max())
plt.ylim(X[:, 1].min(), X[:, 1].max())
plt.show()
